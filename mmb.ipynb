# %%
a=0b111
print('memmay{}'.format(a))
# Out:
# memmay7

# %%
abs(0b1111)
# Out:
# 15

# %%
ascii(1)
# Out:
# '1'

# %%
alp=['a','b','c','d','l','w']
def mm(n):
    if n>'a':
        return True
    return False
print(list(filter(mm,alp)))
# Out:
# ['b', 'c', 'd', 'l', 'w']

# %%
import math

def round_half_up(x):
    return int(math.floor(x + 0.5))
round_half_up(-1.5)
# Out:
# -1

# %%
d={1:2,3:4,5:6}
list(d.keys())
for key,value in d.items():
    print(key,value)
# Out:
# 1 2
# 3 4
# 5 6

# %% [markdown]
# Sets
